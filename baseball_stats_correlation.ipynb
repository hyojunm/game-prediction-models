# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/correlation_data.csv')

# %%
r = np.corrcoef(df['team_xwoba_diff'], df['wins'])
print(f'Correlation coefficient R = {r[0][1]}')
# Out:
# Correlation coefficient R = 0.8811678297098618

# %%
# drawing a scatterplot with regression line
# https://python-graph-gallery.com/scatterplot-with-regression-fit-in-matplotlib/

plt.scatter(df['team_xwoba_diff'], df['wins'])

m, b = np.polyfit(df['team_xwoba_diff'], df['wins'], deg=1)
x = np.linspace(-0.05, 0.05, num=100)

plt.plot(x, m * x + b, color='r', lw=3)

plt.xlabel('Team xwOBA differential')
plt.ylabel('Wins')
plt.title(f'R = {round(r[0][1], 4)}')

plt.show()
