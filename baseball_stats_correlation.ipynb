# %%
# import sys
# !{sys.executable} -m pip install pandas numpy matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/baseball/correlation_data.csv')

# %%
r = np.corrcoef(df['team_xwoba'], df['wins'])
print(f'Correlation coefficient R = {r[0][1]}')
# Out:
# Correlation coefficient R = 0.7248400782777383

# %%
# drawing a scatterplot with regression line
# https://python-graph-gallery.com/scatterplot-with-regression-fit-in-matplotlib/

plt.scatter(df['team_xwoba'], df['wins'])

m, b = np.polyfit(df['team_xwoba'], df['wins'], deg=1)
x = np.linspace(0.285, 0.345, num=100)

plt.plot(x, m * x + b, color='r', lw=3)

plt.gca().set_xlim([0.280, 0.350])

plt.xlabel('Team xwOBA')
plt.ylabel('Wins')
plt.title(f'R = {round(r[0][1], 4)}')

plt.show()
